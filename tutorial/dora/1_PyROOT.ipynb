# %%
from ROOT import gStyle, TCanvas, TGraphErrors, TF1
canvas_1=TCanvas("canvas_1" ,"Data Python" ,200 ,10 ,700 ,500)
# Out:
# Welcome to JupyROOT 6.10/02

# %%
f1 = TF1("f1","abs(sin(x)/x)",0.,10.)
f1.SetParameter(0,1);
f1.SetParameter(1,1);
f1.Draw();
canvas_1.Draw();
