# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.10/02

# %%
c = ROOT.TCanvas("c")
# h = ROOT.TH1F("h","ROOT Histo;X;Y",64,-4,4)
fun1 = ROOT.TF1( 'fun1', 'abs(sin(x)/x)', 0, 10 )
c.SetGridx()
c.SetGridy()
fun1.Draw()
c.Update()
